# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix

# %%
df=pd.read_csv('/content/sample_data/quantvision_financial_dataset_200.csv') #loading data set

# %%
df=df.dropna().reset_index(drop=True) #dropping the empty rows in dataset

# %%
#assigning input features to x and target to y
x=df[["lookback_days","asset_type","market_regime","high_volatility","technical_score", "edge_density",
    "slope_strength", "candlestick_variance","pattern_symmetry"]]
y=df["future_trend"]

# %%
#classifying numeric and string inputs
numeric_features=["lookback_days","high_volatility","technical_score", "edge_density",
                  "slope_strength", "candlestick_variance","pattern_symmetry"]
categorical_features=["asset_type","market_regime"]

# %%
#standardises all input features
numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(drop="first")

preprocess=ColumnTransformer(
    transformers=[
        ("num",numeric_transformer,numeric_features),
        ("cat",categorical_transformer,categorical_features)
    ]
)

# %%
#splitting respectively for training and testing purpose
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=35)

# %%
#implementing logistic regression by using pipeline
clf=Pipeline(steps=[("preprocessor",preprocess),("classifier",LogisticRegression(max_iter=800,random_state=35))])

# %%
#fitting the training samples in the pipeline
clf.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['lookback_days',
#                                                    'high_volatility',
#                                                    'technical_score',
#                                                    'edge_density',
#                                                    'slope_strength',
#                                                    'candlestick_variance',
#                                                    'pattern_symmetry']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['asset_type',
#                                                    'market_regime'])])),
#                 ('classifier',
#                  LogisticRegression(max_iter=800, random_state=35))])

# %%
#building the neural network model
def build_model(input_shape):
    model = keras.Sequential([
        layers.Dense(128, activation='relu', input_shape=(input_shape,)),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')])
    loss_fn=keras.losses.BinaryCrossentropy()
    model.compile(optimizer='adam', loss=loss_fn, metrics=['accuracy'])
    return model

# %%
#conversion of elements of dataset into tensors
x_train_processed = preprocess.fit_transform(x_train)
x_test_processed = preprocess.transform(x_test)

x_train_tf = tf.convert_to_tensor(x_train_processed, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)
x_test_tf = tf.convert_to_tensor(x_test_processed, dtype=tf.float32)
y_test_tf = tf.convert_to_tensor(y_test, dtype=tf.float32)

# %%
#creating model with the required number of features
model = build_model(x_train_processed.shape[1])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#fitting training samples in neural network model
model.fit(x_train_tf, y_train_tf, epochs=200, batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.4437 - loss: 0.7158 - val_accuracy: 0.9062 - val_loss: 0.5753
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8625 - loss: 0.5455 - val_accuracy: 0.9062 - val_loss: 0.4783
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9125 - loss: 0.4468 - val_accuracy: 0.9062 - val_loss: 0.4162
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9396 - loss: 0.3479 - val_accuracy: 0.9062 - val_loss: 0.3785
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9302 - loss: 0.3081 - val_accuracy: 0.9062 - val_loss: 0.3533
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9479 - loss: 0.2499 - val_accuracy: 0.9062 - val_loss: 0.3381
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9104 - loss: 0.2967 - val_accuracy: 0.9062 - val_loss: 0.3202
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.
200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0241 - val_accuracy: 0.9375 - val_loss: 0.1408
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.9375 - val_loss: 0.1395
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0239 - val_accuracy: 0.9375 - val_loss: 0.1364
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.9375 - val_loss: 0.1362
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0301 - val_accuracy: 0.9375 - val_loss: 0.1362
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0255 - val_accuracy: 0.9375 - val_loss: 0.1342
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.9375 - val_loss: 0.1388
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.9375 - val_loss: 0.1354
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 0.9375 - val_loss: 0.1388
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0221 - val_accuracy: 0.9375 - val_loss: 0.1373
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.9375 - val_loss: 0.1411
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.9375 - val_loss: 0.1397
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.9375 - val_loss: 0.1351
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.9375 - val_loss: 0.1387
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.9375 - val_loss: 0.1400
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0184 - val_accuracy: 0.9375 - val_loss: 0.1382
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.9375 - val_loss: 0.1393
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0168 - val_accuracy: 0.9375 - val_loss: 0.1395
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.9375 - val_loss: 0.1386
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.9375 - val_loss: 0.1387
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0171 - val_accuracy: 0.9375 - val_loss: 0.1411
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.9375 - val_loss: 0.1441
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.9375 - val_loss: 0.1419
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.9375 - val_loss: 0.1421
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9375 - val_loss: 0.1417
# Epoch 97/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9375 - val_loss: 0.1398
# Epoch 98/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.9375 - val_loss: 0.1426
# Epoch 99/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9375 - val_loss: 0.1434
# Epoch 100/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.9375 - val_loss: 0.1439
# Epoch 101/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9375 - val_loss: 0.1442
# Epoch 102/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.9375 - val_loss: 0.1451
# Epoch 103/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9375 - val_loss: 0.1497
# Epoch 104/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.9375 - val_loss: 0.1459
# Epoch 105/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.9375 - val_loss: 0.1445
# Epoch 106/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9375 - val_loss: 0.1470
# Epoch 107/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.9375 - val_loss: 0.1487
# Epoch 108/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9375 - val_loss: 0.1503
# Epoch 109/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.9375 - val_loss: 0.1503
# Epoch 110/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.9375 - val_loss: 0.1444
# Epoch 111/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9375 - val_loss: 0.1457
# Epoch 112/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9375 - val_loss: 0.1518
# Epoch 113/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9375 - val_loss: 0.1558
# Epoch 114/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9375 - val_loss: 0.1563
# Epoch 115/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9375 - val_loss: 0.1538
# Epoch 116/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9375 - val_loss: 0.1535
# Epoch 117/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9375 - val_loss: 0.1558
# Epoch 118/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9375 - val_loss: 0.1581
# Epoch 119/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9375 - val_loss: 0.1572
# Epoch 120/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9375 - val_loss: 0.1555
# Epoch 121/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9375 - val_loss: 0.1552
# Epoch 122/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9375 - val_loss: 0.1586
# Epoch 123/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9375 - val_loss: 0.1600
# Epoch 124/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9375 - val_loss: 0.1607
# Epoch 125/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9375 - val_loss: 0.1575
# Epoch 126/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9375 - val_loss: 0.1619
# Epoch 127/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9375 - val_loss: 0.1626
# Epoch 128/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9375 - val_loss: 0.1625
# Epoch 129/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9375 - val_loss: 0.1595
# Epoch 130/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9375 - val_loss: 0.1606
# Epoch 131/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9375 - val_loss: 0.1633
# Epoch 132/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9375 - val_loss: 0.1617
# Epoch 133/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9375 - val_loss: 0.1613
# Epoch 134/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9375 - val_loss: 0.1655
# Epoch 135/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9375 - val_loss: 0.1681
# Epoch 136/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9375 - val_loss: 0.1648
# Epoch 137/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9375 - val_loss: 0.1650
# Epoch 138/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9375 - val_loss: 0.1673
# Epoch 139/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9375 - val_loss: 0.1690
# Epoch 140/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9375 - val_loss: 0.1721
# Epoch 141/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9375 - val_loss: 0.1723
# Epoch 142/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9375 - val_loss: 0.1708
# Epoch 143/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9375 - val_loss: 0.1673
# Epoch 144/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9375 - val_loss: 0.1691
# Epoch 145/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9375 - val_loss: 0.1700
# Epoch 146/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9375 - val_loss: 0.1726
# Epoch 147/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9062 - val_loss: 0.1745
# Epoch 148/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9375 - val_loss: 0.1727
# Epoch 149/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9062 - val_loss: 0.1771
# Epoch 150/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9062 - val_loss: 0.1786
# Epoch 151/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9062 - val_loss: 0.1779
# Epoch 152/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9062 - val_loss: 0.1757
# Epoch 153/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9375 - val_loss: 0.1731
# Epoch 154/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9062 - val_loss: 0.1748
# Epoch 155/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9062 - val_loss: 0.1803
# Epoch 156/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9062 - val_loss: 0.1819
# Epoch 157/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9062 - val_loss: 0.1816
# Epoch 158/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9062 - val_loss: 0.1818
# Epoch 159/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9062 - val_loss: 0.1820
# Epoch 160/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9062 - val_loss: 0.1805
# Epoch 161/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9062 - val_loss: 0.1815
# Epoch 162/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9062 - val_loss: 0.1822
# Epoch 163/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9062 - val_loss: 0.1845
# Epoch 164/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9062 - val_loss: 0.1846
# Epoch 165/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9062 - val_loss: 0.1852
# Epoch 166/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9062 - val_loss: 0.1869
# Epoch 167/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9062 - val_loss: 0.1858
# Epoch 168/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9062 - val_loss: 0.1854
# Epoch 169/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9062 - val_loss: 0.1877
# Epoch 170/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9062 - val_loss: 0.1889
# Epoch 171/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9062 - val_loss: 0.1876
# Epoch 172/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9062 - val_loss: 0.1873
# Epoch 173/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9062 - val_loss: 0.1892
# Epoch 174/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9062 - val_loss: 0.1895
# Epoch 175/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9062 - val_loss: 0.1906
# Epoch 176/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9062 - val_loss: 0.1929
# Epoch 177/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9062 - val_loss: 0.1932
# Epoch 178/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9062 - val_loss: 0.1929
# Epoch 179/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9062 - val_loss: 0.1941
# Epoch 180/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9062 - val_loss: 0.1936
# Epoch 181/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9062 - val_loss: 0.1960
# Epoch 182/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9062 - val_loss: 0.1969
# Epoch 183/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9062 - val_loss: 0.1976
# Epoch 184/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9062 - val_loss: 0.1970
# Epoch 185/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 9.4105e-04 - val_accuracy: 0.9062 - val_loss: 0.1973
# Epoch 186/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9062 - val_loss: 0.1986
# Epoch 187/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9062 - val_loss: 0.1996
# Epoch 188/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9062 - val_loss: 0.2000
# Epoch 189/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9062 - val_loss: 0.1993
# Epoch 190/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 9.1361e-04 - val_accuracy: 0.9062 - val_loss: 0.2015
# Epoch 191/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9062 - val_loss: 0.2057
# Epoch 192/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9062 - val_loss: 0.2025
# Epoch 193/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9062 - val_loss: 0.2009
# Epoch 194/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 9.8884e-04 - val_accuracy: 0.9062 - val_loss: 0.2008
# Epoch 195/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9062 - val_loss: 0.2027
# Epoch 196/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9062 - val_loss: 0.2078
# Epoch 197/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9062 - val_loss: 0.2060
# Epoch 198/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9062 - val_loss: 0.2053
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9062 - val_loss: 0.2073
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9062 - val_loss: 0.2085

# %%
print("NEURAL NETWORK MODEL EVALUATION:\n")
# Predict probabilities
y_pred_prob=model.predict(x_test_tf)
# Convert probabilities to binary labels (0/1)
y_pred=(y_pred_prob >= 0.5).astype(int).reshape(-1)
y_true=y_test_tf.numpy()
accuracy=accuracy_score(y_true, y_pred)
precision=precision_score(y_true, y_pred)
recall=recall_score(y_true, y_pred)
f1=f1_score(y_true, y_pred)
cm=confusion_matrix(y_true, y_pred)
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("\nConfusion Matrix:")
print(cm)
# Out:
# NEURAL NETWORK MODEL EVALUATION:
#
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Accuracy: 0.95
# Precision: 0.9736842105263158
# Recall: 0.9736842105263158
# F1-score: 0.9736842105263158
#
# Confusion Matrix:
# [[ 1  1]
#  [ 1 37]]

# %%
print("LOGISTIC REGRESSION MODEL EVALUATION:")
y_pred=clf.predict(x_test)
accuracy=accuracy_score(y_test, y_pred)
precision=precision_score(y_test, y_pred)
recall=recall_score(y_test, y_pred)
f1=f1_score(y_test, y_pred)
cm=confusion_matrix(y_test, y_pred)
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("\nConfusion Matrix:")
print(cm)
# Out:
# LOGISTIC REGRESSION MODEL EVALUATION:
# Accuracy: 0.925
# Precision: 0.9487179487179487
# Recall: 0.9736842105263158
# F1-score: 0.961038961038961
#
# Confusion Matrix:
# [[ 0  2]
#  [ 1 37]]

# %% [markdown]
# ***ANALYSIS AND FINANCIAL INTERPRETATION***
# 1. Logistic Regression uses a linear decision boundary but financial markets do not assume a linear decision boundary so it performs well only to a certain extent.
# 2. Neural Networks can work with non-linear relations well so we get better results. This is quite evident from the respective accuracies that we have calculated.
# 3. High volatility leads to failure in making the correct predictions because in these cases the market can respond as bullish or bearish, it is difficult to conclude.
# 4. Trend continuation makes it easy for our model to make the correct prediction.Hence it helps in the achieving high accuracy.
# 5. In case of high volatility, sideways market, candlesticks we are not familiar with , the model fails to take the right decision. Financial markets are affected by external events, some company related news but our model only relies on the statistics and does not understand the sentiments of the people.
